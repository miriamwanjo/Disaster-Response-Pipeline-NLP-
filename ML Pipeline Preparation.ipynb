# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from sqlalchemy import create_engine
from nltk.stem import WordNetLemmatizer

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
import re
from sklearn.multioutput import MultiOutputClassifier
import pickle
from sklearn import metrics
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# load data from database
engine = create_engine('sqlite:///ETL_disaster.db')
df_etl =pd.read_sql('SELECT * from ETL_disaster', engine)
X = df_etl['message']
Y = df_etl.drop(['id', 'message', 'genre', 'original'], axis = 1) #remove the columns without dummies

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=<function tokenize at 0x7fe8a858c620>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False),
#               n_jobs=1))],
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize at 0x7fe8a858c620>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#             n_jobs=1),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 10,
#  'clf__estimator__n_jobs': 1,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'clf__n_jobs': 1}

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', RandomForestClassifier())
    ])

    # train classifier
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)
y_pred_pd = pd.DataFrame(y_pred, columns = y_test.columns)
for column in y_test.columns:
    print('Attribute: {}\n'.format(column))
    print(classification_report(y_test[column],y_pred_pd[column]))
# Out:
# Attribute: related
#
#              precision    recall  f1-score   support
#
#           0       0.56      0.43      0.49      1549
#           1       0.83      0.90      0.86      4960
#           2       0.44      0.09      0.15        45
#
# avg / total       0.76      0.78      0.77      6554
#
# Attribute: request
#
#              precision    recall  f1-score   support
#
#           0       0.88      0.99      0.93      5424
#           1       0.83      0.33      0.47      1130
#
# avg / total       0.87      0.87      0.85      6554
#
# Attribute: offer
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6521
#           1       0.00      0.00      0.00        33
#
# avg / total       0.99      0.99      0.99      6554
#
# Attribute: aid_related
#
#              precision    recall  f1-score   support
#
#           0       0.68      0.91      0.78      3827
#           1       0.77      0.41      0.53      2727
#
# avg / total       0.72      0.70      0.68      6554
#
# Attribute: medical_help
#
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6023
#           1       0.35      0.01      0.02       531
#
# avg / total       0.87      0.92      0.88      6554
#
# Attribute: medical_products
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6232
#           1       0.58      0.03      0.06       322
#
# avg / total       0.93      0.95      0.93      6554
#
# Attribute: search_and_rescue
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6351
#           1       0.33      0.00      0.01       203
#
# avg / total       0.95      0.97      0.95      6554
#
# Attribute: security
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6432
#           1       0.00      0.00      0.00       122
#
# avg / total       0.96      0.98      0.97      6554
#
# Attribute: military
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6338
#           1       0.60      0.01      0.03       216
#
# avg / total       0.96      0.97      0.95      6554
#
# Attribute: child_alone
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Attribute: water
#
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6142
#           1       0.89      0.08      0.15       412
#
# avg / total       0.94      0.94      0.92      6554
#
# Attribute: food
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.99      0.95      5817
#           1       0.82      0.20      0.33       737
#
# avg / total       0.90      0.91      0.88      6554
#
# Attribute: shelter
#
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      5987
#           1       0.93      0.11      0.20       567
#
# avg / total       0.92      0.92      0.89      6554
#
# Attribute: clothing
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6441
#           1       0.67      0.04      0.07       113
#
# avg / total       0.98      0.98      0.98      6554
#
# Attribute: money
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6388
#           1       0.78      0.04      0.08       166
#
# avg / total       0.97      0.98      0.96      6554
#
# Attribute: missing_people
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6478
#           1       0.00      0.00      0.00        76
#
# avg / total       0.98      0.99      0.98      6554
#
# Attribute: refugees
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6314
#           1       0.00      0.00      0.00       240
#
# avg / total       0.93      0.96      0.95      6554
#
# Attribute: death
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6264
#           1       0.75      0.04      0.08       290
#
# avg / total       0.95      0.96      0.94      6554
#
# Attribute: other_aid
#
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5675
#           1       0.55      0.03      0.05       879
#
# avg / total       0.83      0.87      0.81      6554
#
# Attribute: infrastructure_related
#
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6162
#           1       0.00      0.00      0.00       392
#
# avg / total       0.88      0.94      0.91      6554
#
# Attribute: transport
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6242
#           1       0.60      0.01      0.02       312
#
# avg / total       0.94      0.95      0.93      6554
#
# Attribute: buildings
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6216
#           1       0.75      0.02      0.03       338
#
# avg / total       0.94      0.95      0.93      6554
#
# Attribute: electricity
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6409
#           1       0.50      0.01      0.01       145
#
# avg / total       0.97      0.98      0.97      6554
#
# Attribute: tools
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6512
#           1       0.00      0.00      0.00        42
#
# avg / total       0.99      0.99      0.99      6554
#
# Attribute: hospitals
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       0.00      0.00      0.00        65
#
# avg / total       0.98      0.99      0.99      6554
#
# Attribute: shops
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6523
#           1       0.00      0.00      0.00        31
#
# avg / total       0.99      1.00      0.99      6554
#
# Attribute: aid_centers
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6487
#           1       0.00      0.00      0.00        67
#
# avg / total       0.98      0.99      0.98      6554
#
# Attribute: other_infrastructure
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6272
#           1       0.00      0.00      0.00       282
#
# avg / total       0.92      0.96      0.94      6554
#
# Attribute: weather_related
#
#              precision    recall  f1-score   support
#
#           0       0.81      0.97      0.89      4784
#           1       0.84      0.40      0.54      1770
#
# avg / total       0.82      0.82      0.79      6554
#
# Attribute: floods
#
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      6040
#           1       0.91      0.09      0.17       514
#
# avg / total       0.93      0.93      0.90      6554
#
# Attribute: storm
#
#              precision    recall  f1-score   support
#
#           0       0.92      0.99      0.96      5957
#           1       0.72      0.17      0.27       597
#
# avg / total       0.90      0.92      0.89      6554
#
# Attribute: fire
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6490
#           1       0.00      0.00      0.00        64
#
# avg / total       0.98      0.99      0.99      6554
#
# Attribute: earthquake
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.97      5958
#           1       0.87      0.39      0.54       596
#
# avg / total       0.94      0.94      0.93      6554
#
# Attribute: cold
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6427
#           1       1.00      0.01      0.02       127
#
# avg / total       0.98      0.98      0.97      6554
#
# Attribute: other_weather
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6221
#           1       0.80      0.01      0.02       333
#
# avg / total       0.94      0.95      0.93      6554
#
# Attribute: direct_report
#
#              precision    recall  f1-score   support
#
#           0       0.85      0.98      0.91      5286
#           1       0.75      0.27      0.40      1268
#
# avg / total       0.83      0.84      0.81      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
def tuned_model():
    pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])
    parameters = {'vect__min_df': [1, 3, 5],
              'tfidf__use_idf':[True, False],
              'clf__estimator__n_estimators':[10, 25], 
              'clf__estimator__min_samples_split':[2, 3, 10]}

    cv = GridSearchCV(pipeline, param_grid=parameters, verbose = 10)
    
    return cv

# %%
model = tuned_model()
model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1, score=0.2233750381446445, total=  46.1s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   55.9s remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1, score=0.22017088800732376, total=  45.9s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.9min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1, score=0.2191028379615502, total=  46.8s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.8min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3, score=0.23268233140067135, total=  40.2s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  3.6min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3, score=0.22352761672261215, total=  39.3s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.4min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3, score=0.2268843454379005, total=  40.6s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  5.3min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5, score=0.23039365273115656, total=  39.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  6.1min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5, score=0.22947818126335062, total=  38.9s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  6.9min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5, score=0.22657918828196522, total=  39.1s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  7.7min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1, score=0.22490082392432104, total=  45.3s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1, score=0.22673176685993288, total=  45.7s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1, score=0.221391516631065, total=  46.9s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3, score=0.22520598108025633, total=  38.3s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3, score=0.2279523954836741, total=  38.2s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3, score=0.21986573085138847, total=  38.5s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5, score=0.23405553860238024, total=  36.8s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5, score=0.22093378089716204, total=  36.8s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5, score=0.2393957888312481, total=  37.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1, score=0.23176685993286542, total= 1.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1, score=0.22245956667683858, total= 1.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1, score=0.21589868782422947, total= 1.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=3, score=0.23588648153799208, total= 1.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=3, score=0.2331400671345743, total= 1.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=3, score=0.23725968873970094, total= 1.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=5, score=0.23863289594140982, total= 1.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=5, score=0.23466585291425085, total= 1.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=5, score=0.23832773878547453, total= 1.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=1, score=0.2259688739700946, total= 1.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=1, score=0.2259688739700946, total= 1.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=1, score=0.22444308819041806, total= 1.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=3, score=0.24336283185840707, total= 1.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=3, score=0.23008849557522124, total= 1.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=3, score=0.23390296002441258, total= 1.4min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=5, score=0.23954836740921576, total= 1.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=5, score=0.2413793103448276, total= 1.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=25, tfidf__use_idf=False, vect__min_df=5, score=0.23375038144644492, total= 1.3min
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1, score=0.21132133048519988, total=  43.7s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1, score=0.2090326518156851, total=  43.6s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=1, score=0.2148306377784559, total=  43.2s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3, score=0.21986573085138847, total=  38.3s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3, score=0.21727189502593836, total=  38.1s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=3, score=0.22123893805309736, total=  37.6s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5, score=0.22154409520903265, total=  37.7s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5, score=0.22703692401586817, total=  37.4s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=True, vect__min_df=5, score=0.22184925236496797, total=  37.5s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1, score=0.21727189502593836, total=  42.8s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1, score=0.21406774488861763, total=  42.1s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=1, score=0.22017088800732376, total=  42.4s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3, score=0.21742447360390602, total=  36.3s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3, score=0.2187976808056149, total=  36.6s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=3, score=0.20949038754958804, total=  36.7s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5, score=0.22902044552944767, total=  35.5s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5, score=0.22352761672261215, total=  35.4s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, tfidf__use_idf=False, vect__min_df=5, score=0.2262740311260299, total=  35.6s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=25, tfidf__use_idf=True, vect__min_df=1

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
new_y_pred = model.predict(X_test)
new_y_pred_pd = pd.DataFrame(new_y_pred, columns = y_test.columns)
for column in y_test.columns:
    print('Attribute: {}\n'.format(column))
    print(classification_report(y_test[column],new_y_pred_pd[column]))

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
def other_model():
    pipeline2 = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ]))
        ])),

        ('clf', MultiOutPutClassifier(SVC()))
    ])

    parameters = { 
        'features__text_pipeline__vect__max_df': (1.0),
        'features__text_pipeline__tfidf__use_idf': (True),
        'clf__estimator_kernel': ['poly'],
        'clf__estimator_degree': [1, 2, 3]
        
    }

    cv1 = GridSearchCV(pipeline2, param_grid=parameters)

    return cv1

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
new_pickle = open('disaster_reponse.sav', 'wb')
pickle.dump(tuned_model, new_pickle)
new_pickle.close()

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.

# %%
# import libraries
import pandas as pd
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from sqlalchemy import create_engine
from nltk.stem import WordNetLemmatizer

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
import re
from sklearn.multioutput import MultiOutputClassifier
import pickle
from sklearn import metrics


# load data from database
def load_data(database_filepath):
    '''
    INPUT
        database_filepath - path where the database is stored
    OUTPUT
        X - Returns all features
        Y - data frame with all the numerical columns
        '''
    engine = create_engine('sqlite:///ETL_disaster.db')
    df_etl =pd.read_sql('SELECT * from ETL_disaster', engine)
    X = df_etl['message']
    Y = df_etl.drop(['id', 'message', 'genre', 'original'], axis = 1) #remove the columns without dummies
    return X, Y

def tokenize(text):
    '''
    INPUT
        text - text to be tokenized
    OUTPUT
        returns refined text that has been tokenized, all lower cased and lemmatized
    '''
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

def tuned_model(X_train, y_train):
    '''
    INPUT
        X_train - data to be used as training features
        y_train - training data labels
    OUPUT
        returns a pipeline that is applied to grid search to create a new model
        
    '''
    pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])
    parameters = {'vect__min_df': [1, 3, 5],
              'tfidf__use_idf':[True, False],
              'clf__estimator__n_estimators':[10, 25], 
              'clf__estimator__min_samples_split':[2, 3, 10]}

    cv = GridSearchCV(pipeline, param_grid=parameters, verbose = 10)
   
    return cv
def model_testing(model, X_test, y_test):
    '''
    INPUT
        model - new model after training
        X_test - testing set data features
        y_test - testing set data labels
    OUTPUT
        returns the classification report 
    '''
    model.fit(X_train, y_train)     
    new_y_pred = model.predict(X_test)
    new_y_pred_pd = pd.DataFrame(new_y_pred, columns = y_test.columns)
    for column in y_test.columns:
        print('Attribute: {}\n'.format(column))
        print(classification_report(y_test[column],new_y_pred_pd[column]))
        
def save_data(model, new_model_filepath):
    '''
    INPUT
        model - the final model
        new_model_filepath - name for the new model
    OUTPUT
        save model as a pickle file
    '''
    new_pickle = open('new_model_filepath', 'wb')
    pickle.dump(model, new_pickle)
    new_pickle.close()
    
def main():
    if len(sys.argv) == 3:
        database_filepath, model_filepath = sys.argv[1:]
        print('Loading data...\n    DATABASE: {}'.format(database_filepath))
        X, Y = load_data(database_filepath)
        X_train, X_test, y_train, y_test = train_test_split(X, Y)
        
       
        model = build_model(X_train,y_train)
        print('Building and Tuning model')
        
        print('Training the model')
        model = tuned_model()
        model.fit(X_train, y_train)
        
        print('Testing the new model and printing a classification report')
        model_testing(model, X_test, y_test)
        
   
        
        
        print('Model saved as MODEL: {}'.format(new_model_filepath))
        save_model(model, new_model_filepath)

        print('model saved!')


if __name__ == '__main__':
    main()
